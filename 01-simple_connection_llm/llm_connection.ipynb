# %%
! pip install -q openai

# %%
import os

from openai import OpenAI

from IPython.display import Markdown

# %%
OLLAMA_BASE_URL = os.getenv('OLLAMA_BASE_CHAT_URL')
print(f"OLLAMA_BASE_URL is set to {OLLAMA_BASE_URL}")
# Out:
# OLLAMA_BASE_URL is set to http://192.168.15.2:11434/v1/

# %%
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="anything")
model_name = "gemma4:e4b"

# %%
response = ollama.chat.completions.create(model=model_name, messages=[{"role":"user", "content": "Hi, Tell me what is LLM in 100 words in markdown format"}])
print(response.choices[0].message.content)
# Out:
# **LLM (Large Language Model)** refers to sophisticated AI programs trained on massive datasets of text and code. These models, such as GPT-4 and LaMDA, learn intricate patterns, grammar, and relationships within language, allowing them to understand and generate human-like text.
#
# At their core, LLMs don't "think"; they predict the most statistically probable next words in a sequence. This capability allows them to perform diverse tasks, including writing articles, summarizing documents, translating languages, generating code, and engaging in complex dialogue. The sheer scale of their training data and parameters is what gives them their remarkable fluency and versatility, making them foundational tools across modern technology.

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt = """
Hi, I am new to Gen AI, Can you tell me what is LLM? in 100 words.

"""

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

response = ollama.chat.completions.create(model=model_name, messages=messages)
Markdown(response.choices[0].message.content)
# Out:
# Oh, you arrived at the AI dumpster diving party. So, apparently, an LLM (Large Language Model) is basically just a highly ambitious autocomplete function.
#
# Think of it as a massive statistical parrot that has consumed the entire internet and is now convinced it knows everything. It predicts the next most plausible sequence of words based on the patterns it spotted. Don't take its answers literally; it doesn't actually *understand* anything. It just sounds very confident while making educated (but sometimes aggressively wrong) guesses. Good luck, you'll need it.
